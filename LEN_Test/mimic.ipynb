# %%
import pandas as pd
import numpy as np
import torch
from sklearn.preprocessing import KBinsDiscretizer, OneHotEncoder
from experiments.data.load_datasets import load_mimic
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# /var/folders/vd/fbcrpjbs43x7lvny_h4rmzz40000gn/T/ipykernel_35403/3088570464.py in <module>
#       3 import torch
#       4 from sklearn.preprocessing import KBinsDiscretizer, OneHotEncoder
# ----> 5 from experiments.data.load_datasets import load_mimic
#       6
#
# ModuleNotFoundError: No module named 'experiments'

# %%
df = pd.read_csv("StaticData.csv")
df = df.drop(['PatientID', 'deathperiod'], axis=1)
df.head()
# Out:
#    los  gender    age  comorbidity  sofa  respiration  coagulation  liver  \
# 0    9       1  74.19            7     7          0.0          1.0    NaN
# 1    2       0  75.00            4     2          NaN          0.0    0.0
# 2   16       0  51.92            4     2          NaN          0.0    NaN
# 3   12       0  51.73          -13     4          2.0          2.0    NaN
# 4    7       0  62.07            0     3          0.0          2.0    NaN
#
#    renal  cardiovascular  cns
# 0    0.0             3.0  3.0
# 1    1.0             NaN  1.0
# 2    0.0             NaN  2.0
# 3    0.0             NaN  0.0
# 4    1.0             NaN  0.0

# %%
for col in df.columns:
    df[col] = df[col].map(lambda x: 4 if str(x) == 'NaN' else x)

df.head()
# Out:
#    los  gender    age  comorbidity  sofa  respiration  coagulation  liver  \
# 0    9       1  74.19            7     7          0.0          1.0    NaN
# 1    2       0  75.00            4     2          NaN          0.0    0.0
# 2   16       0  51.92            4     2          NaN          0.0    NaN
# 3   12       0  51.73          -13     4          2.0          2.0    NaN
# 4    7       0  62.07            0     3          0.0          2.0    NaN
#
#    renal  cardiovascular  cns
# 0    0.0             3.0  3.0
# 1    1.0             NaN  1.0
# 2    0.0             NaN  2.0
# 3    0.0             NaN  0.0
# 4    1.0             NaN  0.0

# %%
df.describe()
# Out:
#                los       gender          age  comorbidity         sofa  \
# count  5262.000000  5262.000000  5262.000000  5262.000000  5262.000000
# mean     14.668757     0.382554    75.049002     9.801026     4.794185
# std      14.101457     0.486057    50.553676     9.671438     2.694694
# min       1.000000     0.000000    16.010000   -16.000000     2.000000
# 25%       6.000000     0.000000    55.410000     2.000000     3.000000
# 50%      10.000000     0.000000    68.300000     9.000000     4.000000
# 75%      18.000000     1.000000    78.525000    16.000000     6.000000
# max     202.000000     1.000000   306.880000    47.000000    22.000000
#
#        respiration  coagulation        liver        renal  cardiovascular  \
# count  3311.000000  5227.000000  2254.000000  5261.000000     1294.000000
# mean      1.987315     0.674957     0.696983     1.017297        3.238022
# std       1.374066     0.892066     1.051290     1.263514        0.706116
# min       0.000000     0.000000     0.000000     0.000000        0.000000
# 25%       0.000000     0.000000     0.000000     0.000000        3.000000
# 50%       2.000000     0.000000     0.000000     1.000000        3.000000
# 75%       3.000000     1.000000     1.000000     2.000000        4.000000
# max       4.000000     4.000000     4.000000     4.000000        4.000000
#
#                cns
# count  5212.000000
# mean      0.768611
# std       1.140061
# min       0.000000
# 25%       0.000000
# 50%       0.000000
# 75%       1.000000
# max       4.000000

# %%
print(df.shape)
df = df.dropna()
df.shape
# Out:
# (5262, 11)
# (484, 11)

# %%
categories = {0: 'very low', 1: 'low', 2: 'medium', 3: 'high', 4: 'very high'}

bins = 3

est = KBinsDiscretizer(n_bins=bins, encode='ordinal', strategy='uniform')
est.fit(df)

dfTransformed = pd.DataFrame(est.transform(df), columns=data.feature_names)
dfTransformed.head()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# /var/folders/vd/fbcrpjbs43x7lvny_h4rmzz40000gn/T/ipykernel_34025/2450957015.py in <module>
#       4
#       5 est = KBinsDiscretizer(n_bins=bins, encode='ordinal', strategy='uniform')
# ----> 6 est.fit(df)
#       7
#       8 dfTransformed = pd.DataFrame(est.transform(df), columns=data.feature_names)
#
# ~/Library/Python/3.8/lib/python/site-packages/sklearn/preprocessing/_discretization.py in fit(self, X, y)
#     161             Returns the instance itself.
#     162         """
# --> 163         X = self._validate_data(X, dtype="numeric")
#     164
#     165         supported_dtype = (np.float64, np.float32)
#
# ~/Library/Python/3.8/lib/python/site-packages/sklearn/base.py in _validate_data(self, X, y, reset, validate_separately, **check_params)
#     559             raise ValueError("Validation should be done on X, y or both.")
#     560         elif not no_val_X and no_val_y:
# --> 561             X = check_array(X, **check_params)
#     562             out = X
#     563         elif no_val_X and not no_val_y:
#
# ~/Library/Python/3.8/lib/python/site-packages/sklearn/utils/validation.py in check_array(array, accept_sparse, accept_large_sparse, dtype, order, copy, force_all_finite, ensure_2d, allow_nd, ensure_min_samples, ensure_min_features, estimator)
#     790
#     791         if force_all_finite:
# --> 792             _assert_all_finite(array, allow_nan=force_all_finite == "allow-nan")
#     793
#     794     if ensure_min_samples > 0:
#
# ~/Library/Python/3.8/lib/python/site-packages/sklearn/utils/validation.py in _assert_all_finite(X, allow_nan, msg_dtype)
#     112         ):
#     113             type_err = "infinity" if allow_nan else "NaN, infinity"
# --> 114             raise ValueError(
#     115                 msg_err.format(
#     116                     type_err, msg_dtype if msg_dtype is not None else X.dtype
#
# ValueError: Input contains NaN, infinity or a value too large for dtype('float64').
